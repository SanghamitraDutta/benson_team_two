# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns

from IPython.display import Image

# enables inline plots, without it plots don't show up in the notebook
# %matplotlib inline


# various options in pandas
pd.set_option('display.max_columns', 25)
pd.set_option('display.max_rows', 400)
pd.set_option('display.precision', 3)

# %%
# Source: http://web.mta.info/developers/turnstile.html
def get_data(week_nums):
    url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    dfs = [] #empty list to input weekly turnstile data into
    for week_num in week_nums:
        # concat our week onto url.. 
        file_url = url.format(week_num)
        dfs.append(pd.read_csv(file_url))
    return pd.concat(dfs)
        
week_nums = [170429, 170506, 170513, 170520, 170527]
df = get_data(week_nums)
df.rename(columns=lambda x: x.strip(), inplace = True)
#df.head(2)

# %%
df["DATE_TIME"] = pd.to_datetime(df.DATE + " " +df.TIME, format="%m/%d/%Y %H:%M:%S")
#df.head(3)

# %%
#calc time diff
df['TIMEDIFF'] = df['DATE_TIME'].diff()
mask = df.UNIT != df.UNIT.shift(1)
mask2 = df.SCP != df.SCP.shift(1)
df['TIMEDIFF'][mask] = np.nan
df['TIMEDIFF'][mask2] = np.nan
# Out:
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df.TIMEDIFF.value_counts() #check counts
# Out:
# 0 days 04:00:00    880786
# 0 days 04:12:00     60565
# 0 days 08:00:00      2127
# 0 days 04:26:00       717
# 0 days 00:01:20       370
# 0 days 12:00:00       214
# 0 days 00:01:21       198
# 0 days 16:00:00       127
# 0 days 00:01:33        75
# 0 days 04:11:59        68
# 0 days 00:01:41        59
# 0 days 00:01:07        59
# 0 days 20:00:00        54
# 0 days 00:01:25        53
# 0 days 00:01:31        47
# 0 days 00:01:22        45
# 0 days 00:01:05        44
# 0 days 00:01:36        42
# 0 days 00:01:15        37
# 0 days 00:00:26        37
# 0 days 00:01:19        35
# 0 days 00:01:14        35
# 0 days 01:44:21        33
# 0 days 00:01:18        32
# 0 days 03:59:59        31
# 0 days 03:59:34        30
# 0 days 00:01:23        29
# 0 days 00:01:24        28
# 0 days 00:57:10        28
# 0 days 00:01:58        28
# 0 days 01:11:54        28
# 0 days 00:05:31        27
# 0 days 00:01:13        26
# 0 days 02:02:09        26
# 2 days 04:00:00        25
# 0 days 00:09:58        25
# 0 days 00:01:06        24
# 0 days 00:01:03        24
# 0 days 00:01:29        24
# 0 days 00:02:43        23
# 0 days 00:57:40        23
# 0 days 01:57:51        22
# 0 days 02:14:21        22
# 0 days 00:24:06        22
# 0 days 02:53:55        22
# 0 days 00:03:15        22
# 0 days 03:58:02        22
# 0 days 01:06:05        22
# 0 days 03:35:54        22
# 0 days 02:59:05        21
# 0 days 01:00:55        21
# 0 days 02:44:48        20
# 0 days 01:15:12        20
# 0 days 02:15:47        19
# 0 days 01:46:45        19
# 0 days 00:06:13        19
# 0 days 04:00:01        19
# 0 days 03:19:04        19
# 0 days 00:40:56        19
# 0 days 00:02:04        18
# 0 days 00:05:40        18
# 0 days 03:52:56        18
# 0 days 03:54:38        18
# 0 days 01:15:28        18
# 0 days 03:11:59        18
# 0 days 02:44:32        18
# 0 days 03:41:59        18
# 0 days 00:48:01        18
# 0 days 01:20:44        18
# 0 days 00:16:41        18
# 0 days 00:05:22        18
# 0 days 02:39:16        18
# 0 days 00:01:28        17
# 0 days 02:32:50        17
# 0 days 00:01:39        17
# 0 days 00:23:26        16
# 0 days 00:20:44        16
# 0 days 00:03:17        16
# 0 days 03:58:04        16
# 0 days 00:13:41        16
# 23         9
# 14         7
# 15         4
# 17         4
# 11         4
# 13         3
# 19         3
# 22         2
# 21         2
# 18         1
# Name: HRSDIFF, dtype: int64

# %%
df = df[df.HRSDIFF <= 4] #filter out anything greater than 4 hrs
df.HRSDIFF.value_counts() #check counts
# Out:
# 4    943315
# 0      4435
# 1      2277
# 2      2114
# 3      1764
# Name: HRSDIFF, dtype: int64

# %%
df['DATE'] = pd.to_datetime(df['DATE'])
df['DAY_OF_WK'] = df['DATE'].dt.weekday_name
df['DAY_OF_WK_N'] = df['DATE'].dt.weekday
df.head()
# Out:
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2017-04-22  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2017-04-22  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2017-04-22  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2017-04-22  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT 2017-04-22  20:00:00
#
#       DESC  ENTRIES    EXITS  DELTA_EXITS  DELTA_ENTRIES           DATE_TIME  \
# 1  REGULAR  6148080  2082123          3.0           55.0 2017-04-22 04:00:00
# 2  REGULAR  6148101  2082157         34.0           21.0 2017-04-22 08:00:00
# 3  REGULAR  6148224  2082251         94.0          123.0 2017-04-22 12:00:00
# 4  REGULAR  6148524  2082316         65.0          300.0 2017-04-22 16:00:00
# 5  REGULAR  6148910  2082368         52.0          386.0 2017-04-22 20:00:00
#
#   TIMEDIFF HRSDIFF DAY_OF_WK  DAY_OF_WK_N
# 1 04:00:00       4  Saturday            5
# 2 04:00:00       4  Saturday            5
# 3 04:00:00       4  Saturday            5
# 4 04:00:00       4  Saturday            5
# 5 04:00:00       4  Saturday            5

# %%
#sort strings in 'linename'

df['LINESORT'] = df.LINENAME.apply(sorted)
# Out:
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df['LINESORT'] = df.LINESORT.apply(''.join)
df['STAT_MERGE'] = df['STATION'] + '-' + df['LINESORT']
#df[df['DAY_OF_WK'] == 'Monday'].head(2)
df.head()
# Out:
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2017-04-22  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2017-04-22  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2017-04-22  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2017-04-22  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT 2017-04-22  20:00:00
#
#       DESC  ENTRIES    EXITS  DELTA_EXITS  DELTA_ENTRIES           DATE_TIME  \
# 1  REGULAR  6148080  2082123          3.0           55.0 2017-04-22 04:00:00
# 2  REGULAR  6148101  2082157         34.0           21.0 2017-04-22 08:00:00
# 3  REGULAR  6148224  2082251         94.0          123.0 2017-04-22 12:00:00
# 4  REGULAR  6148524  2082316         65.0          300.0 2017-04-22 16:00:00
# 5  REGULAR  6148910  2082368         52.0          386.0 2017-04-22 20:00:00
#
#   TIMEDIFF HRSDIFF DAY_OF_WK  DAY_OF_WK_N LINESORT     STAT_MERGE
# 1 04:00:00       4  Saturday            5  456NQRW  59 ST-456NQRW
# 2 04:00:00       4  Saturday            5  456NQRW  59 ST-456NQRW
# 3 04:00:00       4  Saturday            5  456NQRW  59 ST-456NQRW
# 4 04:00:00       4  Saturday            5  456NQRW  59 ST-456NQRW
# 5 04:00:00       4  Saturday            5  456NQRW  59 ST-456NQRW

# %%
#calculate change in entries
df['DELTA_ENTRIES'] = df['ENTRIES'].diff()
mask = df.UNIT != df.UNIT.shift(1)
mask2 = df.SCP != df.SCP.shift(1)
df['DELTA_ENTRIES'][mask] = np.nan
df['DELTA_ENTRIES'][mask2] = np.nan

#df.head(3)
# Out:
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/krw252/anaconda/lib/python3.6/site-packages/pandas/core/generic.py:5088: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /Users/krw252/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#calculate change in exits
df['DELTA_EXITS'] = df['EXITS'].diff()
mask = df.UNIT != df.UNIT.shift(1)
mask2 = df.SCP != df.SCP.shift(1)
df['DELTA_EXITS'][mask] = np.nan
df['DELTA_EXITS'][mask2] = np.nan

#df.head(3)
# Out:
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Users/krw252/anaconda/lib/python3.6/site-packages/pandas/core/generic.py:5088: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /Users/krw252/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df = df[df.DESC == 'REGULAR']
df.head(3)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION       DATE      TIME  \
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2017-04-22  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2017-04-22  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2017-04-22  12:00:00
#
#       DESC  ENTRIES    EXITS  DELTA_EXITS  DELTA_ENTRIES           DATE_TIME  \
# 1  REGULAR  6148080  2082123          NaN            NaN 2017-04-22 04:00:00
# 2  REGULAR  6148101  2082157         34.0           21.0 2017-04-22 08:00:00
# 3  REGULAR  6148224  2082251         94.0          123.0 2017-04-22 12:00:00
#
#   TIMEDIFF HRSDIFF DAY_OF_WK  DAY_OF_WK_N LINESORT     STAT_MERGE
# 1 04:00:00       4  Saturday            5  456NQRW  59 ST-456NQRW
# 2 04:00:00       4  Saturday            5  456NQRW  59 ST-456NQRW
# 3 04:00:00       4  Saturday            5  456NQRW  59 ST-456NQRW

# %%
df.DESC.value_counts()
# Out:
# REGULAR    953905
# Name: DESC, dtype: int64

# %%
#account for backcounting units
df['DELTA_ENTRIES'] = abs(df['DELTA_ENTRIES'])
df['DELTA_EXITS'] = abs(df['DELTA_EXITS'])

# %%
#account for super high counts due to bad data or counter resets
df.sort_values(by ='DELTA_ENTRIES', ascending = False,inplace=True)
df_filt = df[df.DELTA_ENTRIES < 5000]
df_filt = df_filt[df_filt.DELTA_EXITS < 5000]

df_filt.head(5)
# Out:
#          C/A  UNIT       SCP          STATION LINENAME DIVISION       DATE  \
# 10243   A060  R001  00-00-00  WHITEHALL S-FRY      R1W      BMT 2017-05-24
# 151276  R240  R047  00-00-01  GRD CNTRL-42 ST    4567S      IRT 2017-05-24
# 151834  R238  R046  00-03-02  GRD CNTRL-42 ST    4567S      IRT 2017-05-10
# 128664  R138  R293  00-00-04   34 ST-PENN STA   123ACE      IRT 2017-05-25
# 151196  R238  R046  00-03-02  GRD CNTRL-42 ST    4567S      IRT 2017-05-16
#
#             TIME     DESC   ENTRIES    EXITS  DELTA_EXITS  DELTA_ENTRIES  \
# 10243   10:33:56  REGULAR   2429111  1925681       2172.0         4902.0
# 151276  01:00:00  REGULAR     79374    81698       1365.0         4591.0
# 151834  20:00:00  REGULAR  28652861  8757415         16.0         4481.0
# 128664  18:00:00  REGULAR  17396517  8182957       1516.0         4349.0
# 151196  20:00:00  REGULAR  28683723  8769962         31.0         4310.0
#
#                  DATE_TIME TIMEDIFF HRSDIFF  DAY_OF_WK  DAY_OF_WK_N LINESORT  \
# 10243  2017-05-24 10:33:56 02:32:55       2  Wednesday            2      1RW
# 151276 2017-05-24 01:00:00 04:00:00       4  Wednesday            2    4567S
# 151834 2017-05-10 20:00:00 04:00:00       4  Wednesday            2    4567S
# 128664 2017-05-25 18:00:00 04:00:00       4   Thursday            3   123ACE
# 151196 2017-05-16 20:00:00 04:00:00       4    Tuesday            1    4567S
#
#                    STAT_MERGE
# 10243     WHITEHALL S-FRY-1RW
# 151276  GRD CNTRL-42 ST-4567S
# 151834  GRD CNTRL-42 ST-4567S
# 128664  34 ST-PENN STA-123ACE
# 151196  GRD CNTRL-42 ST-4567S

# %%
df_filt.sort_values(by ='DELTA_EXITS', ascending = False,inplace=True)
df_filt.head(5)
# Out:
#           C/A  UNIT       SCP          STATION      LINENAME DIVISION  \
# 95296    N519  R461  00-00-00  B'WAY-LAFAYETTE         BDFQ6      IND
# 49024   N063A  R011  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 153200   R238  R046  00-03-00  GRD CNTRL-42 ST         4567S      IRT
# 153206   R238  R046  00-03-00  GRD CNTRL-42 ST         4567S      IRT
# 153194   R238  R046  00-03-00  GRD CNTRL-42 ST         4567S      IRT
#
#              DATE      TIME     DESC   ENTRIES     EXITS  DELTA_EXITS  \
# 95296  2017-05-23  21:00:00  REGULAR    362696    982522       4953.0
# 49024  2017-05-22  20:00:00  REGULAR  16459422  57736969       4888.0
# 153200 2017-04-26  12:00:00  REGULAR  13464905   4960372       4876.0
# 153206 2017-04-27  12:00:00  REGULAR  13469687   4973876       4870.0
# 153194 2017-04-25  12:00:00  REGULAR  13462328   4945957       4868.0
#
#         DELTA_ENTRIES           DATE_TIME TIMEDIFF HRSDIFF  DAY_OF_WK  \
# 95296          1926.0 2017-05-23 21:00:00 04:00:00       4    Tuesday
# 49024            68.0 2017-05-22 20:00:00 04:00:00       4     Monday
# 153200          677.0 2017-04-26 12:00:00 04:00:00       4  Wednesday
# 153206          705.0 2017-04-27 12:00:00 04:00:00       4   Thursday
# 153194          656.0 2017-04-25 12:00:00 04:00:00       4    Tuesday
#
#         DAY_OF_WK_N      LINESORT                    STAT_MERGE
# 95296             1         6BDFQ         B'WAY-LAFAYETTE-6BDFQ
# 49024             0  1237ACENQRSW  42 ST-PORT AUTH-1237ACENQRSW
# 153200            2         4567S         GRD CNTRL-42 ST-4567S
# 153206            3         4567S         GRD CNTRL-42 ST-4567S
# 153194            1         4567S         GRD CNTRL-42 ST-4567S

# %%
#station = df_filt.groupby(['DAY_OF_WK']).agg({'DELTA_ENTRIES' : sum, 'DELTA_EXITS' :sum})
#station.sort_values('DELTA_ENTRIES',ascending = False)

# %%
#full = df_filt.groupby(['DATE_TIME']).DELTA_EXITS.mean() #by date time

# %%
#x = np.array([x for x in range(len(station))])
#y = np.array(full)
#plt.xticks(x, my_xticks)
#plt.bar(x, y)

# %%
day_wk = df_filt.groupby(['DAY_OF_WK_N']).DELTA_EXITS.mean() #define day of week groups
x = np.array([0,1,2,3,4,5,6])
y = np.array(day_wk)
my_xticks = ['Mon', 'Tues', 'Wed','Thur','Fri', 'Sat', 'Sun']
plt.xticks(x, my_xticks)
plt.bar(x, y)
# Out:
# <Container object of 7 artists>

# %%
station = df_filt.groupby(['STAT_MERGE']).DELTA_EXITS.sum().sort_values(ascending=False).head(20)
stat_array = station.index.values

# %%
import pylab as pl

plt.figure(figsize = (10,5))
x = np.array([x for x in range(len(station))])
y = np.array(station)
my_xticks = stat_array
plt.xticks(x, my_xticks)
plot = plt.bar(x, y)
plot[0].set_color(blend_soft_light('r', 5))
plot[5].set_color('r')
pl.xticks(rotation = 'vertical')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-3c4b728ed249> in <module>()
#       7 plt.xticks(x, my_xticks)
#       8 plot = plt.bar(x, y)
# ----> 9 plot[0].set_color(blend_soft_light('r', 5))
#      10 plot[5].set_color('r')
#      11 pl.xticks(rotation = 'vertical')
#
# NameError: name 'blend_soft_light' is not defined

# %%
#break time of day into segments
def get_time_of_day(string):
    hour = int(string.split(":")[0])
    if hour <= 21 and hour > 17:
        tod = "Evening"
    elif hour <= 17 and hour > 13:
        tod = "Afternoon"
    elif hour <= 13 and hour > 9:
        tod = "Morning"
    elif hour <= 9 and hour > 5:
        tod = "Dawn"
    else:
        tod = 'Night'
    return tod

df_filt["TIMEOFDAY"] = df_filt["TIME"].apply(lambda row: get_time_of_day(row))
#b = df_filt.groupby(["UNIT","STATION", "DAY_OF_WK", "TIME"]).agg({"DELTA_EXITS" : sum})
#b.sort_values(by="DELTA_EXITS", ascending=False)

# %%
#rank categorical
#df_filt['DAY_OF_WK'] = pd.Categorical(df_filt['DAY_OF_WK'], ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
#df_filt['TIMEOFDAY'] = pd.Categorical(df_filt['TIMEOFDAY'], ['Dawn','Night', 'Evening','Afternoon','Morning'])

df_filt.head(5)
# Out:
#           C/A  UNIT       SCP          STATION      LINENAME DIVISION  \
# 95296    N519  R461  00-00-00  B'WAY-LAFAYETTE         BDFQ6      IND
# 49024   N063A  R011  00-00-00  42 ST-PORT AUTH  ACENQRS1237W      IND
# 153200   R238  R046  00-03-00  GRD CNTRL-42 ST         4567S      IRT
# 153206   R238  R046  00-03-00  GRD CNTRL-42 ST         4567S      IRT
# 153194   R238  R046  00-03-00  GRD CNTRL-42 ST         4567S      IRT
#
#              DATE      TIME     DESC   ENTRIES     EXITS  DELTA_EXITS  \
# 95296  2017-05-23  21:00:00  REGULAR    362696    982522       4953.0
# 49024  2017-05-22  20:00:00  REGULAR  16459422  57736969       4888.0
# 153200 2017-04-26  12:00:00  REGULAR  13464905   4960372       4876.0
# 153206 2017-04-27  12:00:00  REGULAR  13469687   4973876       4870.0
# 153194 2017-04-25  12:00:00  REGULAR  13462328   4945957       4868.0
#
#         DELTA_ENTRIES           DATE_TIME TIMEDIFF HRSDIFF  DAY_OF_WK  \
# 95296          1926.0 2017-05-23 21:00:00 04:00:00       4    Tuesday
# 49024            68.0 2017-05-22 20:00:00 04:00:00       4     Monday
# 153200          677.0 2017-04-26 12:00:00 04:00:00       4  Wednesday
# 153206          705.0 2017-04-27 12:00:00 04:00:00       4   Thursday
# 153194          656.0 2017-04-25 12:00:00 04:00:00       4    Tuesday
#
#         DAY_OF_WK_N      LINESORT                    STAT_MERGE TIMEOFDAY
# 95296             1         6BDFQ         B'WAY-LAFAYETTE-6BDFQ   Evening
# 49024             0  1237ACENQRSW  42 ST-PORT AUTH-1237ACENQRSW   Evening
# 153200            2         4567S         GRD CNTRL-42 ST-4567S   Morning
# 153206            3         4567S         GRD CNTRL-42 ST-4567S   Morning
# 153194            1         4567S         GRD CNTRL-42 ST-4567S   Morning

# %%
#test heat map on one train line
#nqr_59 = df_filt[df_filt['STAT_MERGE'] == '59 ST-NQR456W']
#mask = ['STAT_MERGE','C/A','UNIT','SCP','STATION','LINENAME','DIVISION','DATE','TIME','DESC','ENTRIES','DATE_TIME','DAY_OF_WK_N','EXITS','DELTA_ENTRIES']
#nqr_59.drop(mask,axis=1,inplace=True)
#nqr_59.head()

# %%
#nqr_59['DAY_OF_WK'] = pd.Categorical(nqr_59['DAY_OF_WK'], ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
#nqr_59['TIMEOFDAY'] = pd.Categorical(nqr_59['TIMEOFDAY'], ['Dawn','Night', 'Evening','Afternoon','Morning'])

# Load pivot of mean EXITS by TIMEGROUP, DAY_OF_WK
#exits_test = nqr_59.pivot_table(index = "TIMEOFDAY", columns = "DAY_OF_WK", values = "DELTA_EXITS")

# Draw a heatmap with the numeric values in each cell
#f, ax = plt.subplots(figsize=(9, 6))
#sns.heatmap(exits_test, annot=True, linewidths=.5, ax=ax,square=True)

# %%
#exits = df_filt.pivot_table(index = "TIMEOFDAY", columns = "DAY_OF_WK", values = "DELTA_EXITS",aggfunc='sum')

# Draw a heatmap with the numeric values in each cell
#f, ax = plt.subplots(figsize=(9, 6))
#sns.heatmap(exits, annot=False, fmt="n", linewidths=.5, ax=ax,square=True, cmap='PuBu')

# %%
grouped_d = df_filt.groupby(["STAT_MERGE", 'DATE',"DAY_OF_WK", "TIMEOFDAY"], as_index=False).agg({'DELTA_EXITS' : sum})
grouped_d.head(15)
#len(grouped_d)
# Out:
#    STAT_MERGE       DATE DAY_OF_WK  TIMEOFDAY  DELTA_EXITS
# 0      1 AV-L 2017-04-22  Saturday  Afternoon       5019.0
# 1      1 AV-L 2017-04-22  Saturday       Dawn        935.0
# 2      1 AV-L 2017-04-22  Saturday    Evening       6051.0
# 3      1 AV-L 2017-04-22  Saturday    Morning       3412.0
# 4      1 AV-L 2017-04-23    Sunday  Afternoon       3897.0
# 5      1 AV-L 2017-04-23    Sunday       Dawn        641.0
# 6      1 AV-L 2017-04-23    Sunday    Evening       4499.0
# 7      1 AV-L 2017-04-23    Sunday    Morning       2368.0
# 8      1 AV-L 2017-04-23    Sunday      Night       5450.0
# 9      1 AV-L 2017-04-24    Monday  Afternoon       3987.0
# 10     1 AV-L 2017-04-24    Monday       Dawn       3525.0
# 11     1 AV-L 2017-04-24    Monday    Evening       6091.0
# 12     1 AV-L 2017-04-24    Monday    Morning       5700.0
# 13     1 AV-L 2017-04-24    Monday      Night       2602.0
# 14     1 AV-L 2017-04-25   Tuesday  Afternoon       3934.0

# %%
grouped_d[(grouped_d['STAT_MERGE'] == '1 AV-L') & (grouped_d['DAY_OF_WK'] == 'Monday') & (grouped_d['TIMEOFDAY'] == 'Morning')]
# Out:
#     STAT_MERGE       DATE DAY_OF_WK TIMEOFDAY  DELTA_EXITS
# 12      1 AV-L 2017-04-24    Monday   Morning       5700.0
# 46      1 AV-L 2017-05-01    Monday   Morning       5656.0
# 80      1 AV-L 2017-05-08    Monday   Morning       5638.0
# 114     1 AV-L 2017-05-15    Monday   Morning       6128.0
# 148     1 AV-L 2017-05-22    Monday   Morning       5753.0

# %%
grouped_means = grouped_d.groupby(["STAT_MERGE","DAY_OF_WK", "TIMEOFDAY"], as_index=False).DELTA_EXITS.mean()
grouped_means.head(20)
#len(grouped_means)
# Out:
#    STAT_MERGE DAY_OF_WK  TIMEOFDAY  DELTA_EXITS
# 0      1 AV-L    Friday  Afternoon       4540.2
# 1      1 AV-L    Friday       Dawn       3323.0
# 2      1 AV-L    Friday    Evening       6854.8
# 3      1 AV-L    Friday    Morning       5767.6
# 4      1 AV-L    Friday      Night       4192.6
# 5      1 AV-L    Monday  Afternoon       3983.8
# 6      1 AV-L    Monday       Dawn       3449.2
# 7      1 AV-L    Monday    Evening       6281.0
# 8      1 AV-L    Monday    Morning       5775.0
# 9      1 AV-L    Monday      Night       2317.4
# 10     1 AV-L  Saturday  Afternoon       3609.4
# 11     1 AV-L  Saturday       Dawn        739.8
# 12     1 AV-L  Saturday    Evening       4234.2
# 13     1 AV-L  Saturday    Morning       2593.8
# 14     1 AV-L    Sunday  Afternoon       3030.4
# 15     1 AV-L    Sunday       Dawn        504.8
# 16     1 AV-L    Sunday    Evening       3393.6
# 17     1 AV-L    Sunday    Morning       1785.0
# 18     1 AV-L    Sunday      Night       4078.0
# 19     1 AV-L  Thursday  Afternoon       5397.8

# %%
## Our original way of grouping top stations by exits by day times

#grouped_d = df_filt.groupby(["STAT_MERGE", "DAY_OF_WK", "TIMEOFDAY"], as_index=False).agg({"DELTA_EXITS" : sum})

#def top_five(df_filt):
#    days = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
#    times = ['Dawn', 'Morning', 'Afternoon', 'Evening', 'Night']
#    for day in days:
#        for time in times:
#            mask = ((df_filt['DAY_OF_WK'] == day) & (df_filt['TIMEOFDAY'] == time))
#            temp_df = df_filt[mask].sort_values(by = ['DELTA_EXITS'], ascending = False).reset_index()
#            print(day, time,'\n', temp_df.head())
#			
#top_five(grouped_d)

# %%
hubs_mask = ((df_filt.STAT_MERGE == 'GRD CNTRL-42 ST-4567S') | 
                (df_filt.STAT_MERGE == 'TIMES SQ-42 ST-1237ACENQRSW') | 
                (df_filt.STAT_MERGE == '42 ST-PORT AUTH-1237ACENQRSW') |
                (df_filt.STAT_MERGE == '34 ST-PENN STA-ACE') |
                (df_filt.STAT_MERGE == '34 ST-PENN STA-123ACE') |
                (df_filt.STAT_MERGE == '42 ST-PORT AUTH-1237ACEGNRSW'))
no_hubs = df_filt.drop(df_filt[hubs_mask].index)
hubs = df_filt[hubs_mask]
#hubs.head()
no_hubs.head(10)
# Out:
#           C/A  UNIT       SCP          STATION   LINENAME DIVISION       DATE  \
# 95296    N519  R461  00-00-00  B'WAY-LAFAYETTE      BDFQ6      IND 2017-05-23
# 10473    A060  R001  00-00-05  WHITEHALL S-FRY        R1W      BMT 2017-05-24
# 40780    N009  R174  01-00-02           181 ST          A      IND 2017-05-10
# 94315    N506  R022  00-00-00  34 ST-HERALD SQ   BDFMNQRW      IND 2017-04-25
# 120868  PTH21  R540  01-00-00       PATH WTC 2          1      PTH 2017-05-03
# 120326  PTH21  R540  01-00-00       PATH WTC 2          1      PTH 2017-05-10
# 119595  PTH21  R540  01-00-00       PATH WTC 2          1      PTH 2017-05-23
# 146756   R216  R322  01-00-02        SPRING ST          6      IRT 2017-05-03
# 119807  PTH21  R540  01-00-00       PATH WTC 2          1      PTH 2017-05-17
# 187334   R610  R057  00-03-00   ATL AV-BARCLAY  2345BDNQR      IRT 2017-05-10
#
#             TIME     DESC  ENTRIES     EXITS  DELTA_EXITS  DELTA_ENTRIES  \
# 95296   21:00:00  REGULAR   362696    982522       4953.0         1926.0
# 10473   10:33:56  REGULAR  1461675   1724877       4499.0         3918.0
# 40780   21:00:00  REGULAR  8994717  14849124       4411.0         3012.0
# 94315   20:00:00  REGULAR  5168907   8372564       4313.0         2278.0
# 120868  10:29:17  REGULAR    40117    243921       4249.0          102.0
# 120326  10:29:17  REGULAR    47385    288711       4102.0           92.0
# 119595  11:18:12  REGULAR     1095     12477       4048.0           80.0
# 146756  20:00:00  REGULAR  1948786  11982798       3951.0          535.0
# 119807  10:19:03  REGULAR    54381    330612       3940.0           82.0
# 187334  20:00:00  REGULAR  4607959  28935093       3861.0           69.0
#
#                  DATE_TIME TIMEDIFF HRSDIFF  DAY_OF_WK  DAY_OF_WK_N  \
# 95296  2017-05-23 21:00:00 04:00:00       4    Tuesday            1
# 10473  2017-05-24 10:33:56 02:32:55       2  Wednesday            2
# 40780  2017-05-10 21:00:00 04:00:00       4  Wednesday            2
# 94315  2017-04-25 20:00:00 04:00:00       4    Tuesday            1
# 120868 2017-05-03 10:29:17 04:12:00       4  Wednesday            2
# 120326 2017-05-10 10:29:17 04:12:00       4  Wednesday            2
# 119595 2017-05-23 11:18:12 04:12:00       4    Tuesday            1
# 146756 2017-05-03 20:00:00 04:00:00       4  Wednesday            2
# 119807 2017-05-17 10:19:03 04:12:00       4  Wednesday            2
# 187334 2017-05-10 20:00:00 04:00:00       4  Wednesday            2
#
#          LINESORT                STAT_MERGE TIMEOFDAY
# 95296       6BDFQ     B'WAY-LAFAYETTE-6BDFQ   Evening
# 10473         1RW       WHITEHALL S-FRY-1RW   Morning
# 40780           A                  181 ST-A   Evening
# 94315    BDFMNQRW  34 ST-HERALD SQ-BDFMNQRW   Evening
# 120868          1              PATH WTC 2-1   Morning
# 120326          1              PATH WTC 2-1   Morning
# 119595          1              PATH WTC 2-1   Morning
# 146756          6               SPRING ST-6   Evening
# 119807          1              PATH WTC 2-1   Morning
# 187334  2345BDNQR  ATL AV-BARCLAY-2345BDNQR   Evening

# %%
#rank categorical
df_filt['DAY_OF_WK'] = pd.Categorical(df_filt['DAY_OF_WK'], ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
df_filt['TIMEOFDAY'] = pd.Categorical(df_filt['TIMEOFDAY'], ['Dawn','Night', 'Evening','Afternoon','Morning'])

exits = df_filt.pivot_table(index = "TIMEOFDAY", columns = "DAY_OF_WK", values = "DELTA_EXITS",aggfunc='sum')

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(exits, annot=False, fmt="n", linewidths=.5, ax=ax,square=True, cmap='PuBu')

# %%
#rank categorical
no_hubs['DAY_OF_WK'] = pd.Categorical(no_hubs['DAY_OF_WK'], ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
no_hubs['TIMEOFDAY'] = pd.Categorical(no_hubs['TIMEOFDAY'], ['Dawn','Night', 'Evening','Afternoon','Morning'])

exits = no_hubs.pivot_table(index = "TIMEOFDAY", columns = "DAY_OF_WK", values = "DELTA_EXITS",aggfunc='sum')

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(exits, annot=False, fmt="n", linewidths=.5, ax=ax,square=True, cmap='PuBu')
# Out:
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#rank categorical
hubs['DAY_OF_WK'] = pd.Categorical(hubs['DAY_OF_WK'], ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
hubs['TIMEOFDAY'] = pd.Categorical(hubs['TIMEOFDAY'], ['Dawn','Night', 'Evening','Afternoon','Morning'])

exits = hubs.pivot_table(index = "TIMEOFDAY", columns = "DAY_OF_WK", values = "DELTA_EXITS",aggfunc='sum')

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(exits, annot=False, fmt="n", linewidths=.5, ax=ax,square=True, cmap='PuBu')
# Out:
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/krw252/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
(grouped_means
 .sort_values(by=['DAY_OF_WK','TIMEOFDAY', 'DELTA_EXITS'], ascending=[True,True,False])
 .groupby(['DAY_OF_WK','TIMEOFDAY'])
 .head())
# Out:
#                          STAT_MERGE  DAY_OF_WK  TIMEOFDAY  DELTA_EXITS
# 10309         GRD CNTRL-42 ST-4567S     Friday  Afternoon     28037.80
# 2925       34 ST-HERALD SQ-BDFMNQRW     Friday  Afternoon     25900.60
# 884         14 ST-UNION SQ-456LNQRW     Friday  Afternoon     21734.60
# 14878   TIMES SQ-42 ST-1237ACENQRSW     Friday  Afternoon     17109.00
# 3061             34 ST-PENN STA-ACE     Friday  Afternoon     16990.40
# 10310         GRD CNTRL-42 ST-4567S     Friday       Dawn     29049.20
# 885         14 ST-UNION SQ-456LNQRW     Friday       Dawn     18214.40
# 10003            FULTON ST-2345ACJZ     Friday       Dawn     13843.60
# 13412                PATH NEW WTC-1     Friday       Dawn     11186.20
# 2926       34 ST-HERALD SQ-BDFMNQRW     Friday       Dawn     10174.60
# 2927       34 ST-HERALD SQ-BDFMNQRW     Friday    Evening     32644.00
# 10311         GRD CNTRL-42 ST-4567S     Friday    Evening     28591.20
# 3369   42 ST-PORT AUTH-1237ACENQRSW     Friday    Evening     24908.60
# 3063             34 ST-PENN STA-ACE     Friday    Evening     24396.40
# 886         14 ST-UNION SQ-456LNQRW     Friday    Evening     22837.60
# 10312         GRD CNTRL-42 ST-4567S     Friday    Morning     41275.40
# 2928       34 ST-HERALD SQ-BDFMNQRW     Friday    Morning     37422.60
# 3507            47-50 STS ROCK-BDFM     Friday    Morning     34551.20
# 14881   TIMES SQ-42 ST-1237ACENQRSW     Friday    Morning     29531.40
# 10005            FULTON ST-2345ACJZ     Friday    Morning     27431.40
# 3371   42 ST-PORT AUTH-1237ACENQRSW     Friday      Night     12827.20
# 9564                FLUSHING-MAIN-7     Friday      Night     12352.00
# 11233         JKSN HT-ROOSVLT-7EFMR     Friday      Night     10675.75
# 2929       34 ST-HERALD SQ-BDFMNQRW     Friday      Night     10216.20
# 888         14 ST-UNION SQ-456LNQRW     Friday      Night      9697.80
# 10314         GRD CNTRL-42 ST-4567S     Monday  Afternoon     26310.00
# 2930       34 ST-HERALD SQ-BDFMNQRW     Monday  Afternoon     20871.80
# 889         14 ST-UNION SQ-456LNQRW     Monday  Afternoon     19895.20
# 14883   TIMES SQ-42 ST-1237ACENQRSW     Monday  Afternoon     14514.80
# 10007            FULTON ST-2345ACJZ     Monday  Afternoon     13152.20
# 10315         GRD CNTRL-42 ST-4567S     Monday       Dawn     32725.00
# 890         14 ST-UNION SQ-456LNQRW     Monday       Dawn     18857.20
# 10008            FULTON ST-2345ACJZ     Monday       Dawn     16119.40
# 13417                PATH NEW WTC-1     Monday       Dawn     14216.80
# 2931       34 ST-HERALD SQ-BDFMNQRW     Monday       Dawn     11334.80
# 10316         GRD CNTRL-42 ST-4567S     Monday    Evening     30825.00
# 2932       34 ST-HERALD SQ-BDFMNQRW     Monday    Evening     30526.40
# 3374   42 ST-PORT AUTH-1237ACENQRSW     Monday    Evening     27217.60
# 3068             34 ST-PENN STA-ACE     Monday    Evening     26324.80
# 899         14 ST-UNION SQ-456LNQRW     Sunday       Dawn      3133.60
# 10324         GRD CNTRL-42 ST-4567S     Sunday       Dawn      2853.40
# 2940       34 ST-HERALD SQ-BDFMNQRW     Sunday       Dawn      2356.20
# 4505                      72 ST-123     Sunday       Dawn      2075.80
# 7702               CANAL ST-6JNQRWZ     Sunday       Dawn      1865.60
# 2941       34 ST-HERALD SQ-BDFMNQRW     Sunday    Evening     14873.40
# 14894   TIMES SQ-42 ST-1237ACENQRSW     Sunday    Evening     13212.40
# 900         14 ST-UNION SQ-456LNQRW     Sunday    Evening     11071.80
# 3384   42 ST-PORT AUTH-1237ACENQRSW     Sunday    Evening     10689.60
# 10325         GRD CNTRL-42 ST-4567S     Sunday    Evening     10493.80
# 901         14 ST-UNION SQ-456LNQRW     Sunday    Morning     12255.40
# 2942       34 ST-HERALD SQ-BDFMNQRW     Sunday    Morning     10988.20
# 10326         GRD CNTRL-42 ST-4567S     Sunday    Morning      9331.40
# 7704               CANAL ST-6JNQRWZ     Sunday    Morning      8742.20
# 14895   TIMES SQ-42 ST-1237ACENQRSW     Sunday    Morning      8190.00
# 2943       34 ST-HERALD SQ-BDFMNQRW     Sunday      Night     10475.20
# 14896   TIMES SQ-42 ST-1237ACENQRSW     Sunday      Night     10285.20
# 3386   42 ST-PORT AUTH-1237ACENQRSW     Sunday      Night      9797.80
# 11247         JKSN HT-ROOSVLT-7EFMR     Sunday      Night      9163.60
# 9578                FLUSHING-MAIN-7     Sunday      Night      7755.40
# 10328         GRD CNTRL-42 ST-4567S   Thursday  Afternoon     29542.00
# 2944       34 ST-HERALD SQ-BDFMNQRW   Thursday  Afternoon     23971.40
# 903         14 ST-UNION SQ-456LNQRW   Thursday  Afternoon     20549.40
# 14897   TIMES SQ-42 ST-1237ACENQRSW   Thursday  Afternoon     19100.40
# 10022            FULTON ST-2345ACJZ   Thursday  Afternoon     17783.80
# 10329         GRD CNTRL-42 ST-4567S   Thursday       Dawn     31066.20
# 904         14 ST-UNION SQ-456LNQRW   Thursday       Dawn     19337.80
# 10023            FULTON ST-2345ACJZ   Thursday       Dawn     16098.20
# 13432                PATH NEW WTC-1   Thursday       Dawn     14789.00
# 2945       34 ST-HERALD SQ-BDFMNQRW   Thursday       Dawn     10586.20
# 2946       34 ST-HERALD SQ-BDFMNQRW   Thursday    Evening     34116.20
# 10330         GRD CNTRL-42 ST-4567S   Thursday    Evening     32863.40
# 3082             34 ST-PENN STA-ACE   Thursday    Evening     28142.00
# 3389   42 ST-PORT AUTH-1237ACENQRSW   Thursday    Evening     27668.20
# 905         14 ST-UNION SQ-456LNQRW   Thursday    Evening     22757.75
# 10331         GRD CNTRL-42 ST-4567S   Thursday    Morning     41343.80
# 2947       34 ST-HERALD SQ-BDFMNQRW   Thursday    Morning     39724.60
# 3526            47-50 STS ROCK-BDFM   Thursday    Morning     37089.00
# 14900   TIMES SQ-42 ST-1237ACENQRSW   Thursday    Morning     30800.60
# 10025            FULTON ST-2345ACJZ   Thursday    Morning     26208.00
# 3391   42 ST-PORT AUTH-1237ACENQRSW   Thursday      Night     11750.00
# 3050          34 ST-PENN STA-123ACE   Thursday      Night     11300.40
# 11252         JKSN HT-ROOSVLT-7EFMR   Thursday      Night     10266.20
# 11355                KEW GARDENS-EF   Thursday      Night     10059.00
# 9583                FLUSHING-MAIN-7   Thursday      Night      9965.80
# 10333         GRD CNTRL-42 ST-4567S    Tuesday  Afternoon     23272.40
# 2949       34 ST-HERALD SQ-BDFMNQRW    Tuesday  Afternoon     20812.40
# 908         14 ST-UNION SQ-456LNQRW    Tuesday  Afternoon     20002.20
# 14902   TIMES SQ-42 ST-1237ACENQRSW    Tuesday  Afternoon     15466.00
# 10027            FULTON ST-2345ACJZ    Tuesday  Afternoon     13560.80
# 10334         GRD CNTRL-42 ST-4567S    Tuesday       Dawn     34577.40
# 909         14 ST-UNION SQ-456LNQRW    Tuesday       Dawn     19611.00
# 10028            FULTON ST-2345ACJZ    Tuesday       Dawn     16547.00
# 13437                PATH NEW WTC-1    Tuesday       Dawn     14832.80
# 2950       34 ST-HERALD SQ-BDFMNQRW    Tuesday       Dawn     10989.00
# 2951       34 ST-HERALD SQ-BDFMNQRW    Tuesday    Evening     35403.00
# 10335         GRD CNTRL-42 ST-4567S    Tuesday    Evening     30564.40
# 3394   42 ST-PORT AUTH-1237ACENQRSW    Tuesday    Evening     27535.40
# 3087             34 ST-PENN STA-ACE    Tuesday    Evening     27494.20
# 910         14 ST-UNION SQ-456LNQRW    Tuesday    Evening     21404.80
# 10336         GRD CNTRL-42 ST-4567S    Tuesday    Morning     44033.00
# 2952       34 ST-HERALD SQ-BDFMNQRW    Tuesday    Morning     37477.00
# 3531            47-50 STS ROCK-BDFM    Tuesday    Morning     36391.20
# 14905   TIMES SQ-42 ST-1237ACENQRSW    Tuesday    Morning     32367.60
# 10030            FULTON ST-2345ACJZ    Tuesday    Morning     30215.80
# 3055          34 ST-PENN STA-123ACE    Tuesday      Night     10811.40
# 3396   42 ST-PORT AUTH-1237ACENQRSW    Tuesday      Night     10574.80
# 11360                KEW GARDENS-EF    Tuesday      Night     10065.40
# 11257         JKSN HT-ROOSVLT-7EFMR    Tuesday      Night      9467.20
# 9588                FLUSHING-MAIN-7    Tuesday      Night      9316.40
# 10338         GRD CNTRL-42 ST-4567S  Wednesday  Afternoon     25444.20
# 2954       34 ST-HERALD SQ-BDFMNQRW  Wednesday  Afternoon     23392.40
# 913         14 ST-UNION SQ-456LNQRW  Wednesday  Afternoon     21127.00
# 14907   TIMES SQ-42 ST-1237ACENQRSW  Wednesday  Afternoon     17760.80
# 3090             34 ST-PENN STA-ACE  Wednesday  Afternoon     15428.20
# 10339         GRD CNTRL-42 ST-4567S  Wednesday       Dawn     32778.00
# 914         14 ST-UNION SQ-456LNQRW  Wednesday       Dawn     20026.40
# 10033            FULTON ST-2345ACJZ  Wednesday       Dawn     17401.80
# 13442                PATH NEW WTC-1  Wednesday       Dawn     14277.60
# 2955       34 ST-HERALD SQ-BDFMNQRW  Wednesday       Dawn     10789.40
# 2956       34 ST-HERALD SQ-BDFMNQRW  Wednesday    Evening     32807.60
# 10340         GRD CNTRL-42 ST-4567S  Wednesday    Evening     30930.00
# 3399   42 ST-PORT AUTH-1237ACENQRSW  Wednesday    Evening     26885.20
# 3092             34 ST-PENN STA-ACE  Wednesday    Evening     25889.80
# 915         14 ST-UNION SQ-456LNQRW  Wednesday    Evening     22417.60
# 10341         GRD CNTRL-42 ST-4567S  Wednesday    Morning     44831.60
# 2957       34 ST-HERALD SQ-BDFMNQRW  Wednesday    Morning     39865.20
# 3536            47-50 STS ROCK-BDFM  Wednesday    Morning     36717.60
# 14910   TIMES SQ-42 ST-1237ACENQRSW  Wednesday    Morning     33157.20
# 10035            FULTON ST-2345ACJZ  Wednesday    Morning     29535.40
# 3401   42 ST-PORT AUTH-1237ACENQRSW  Wednesday      Night     11696.80
# 10342         GRD CNTRL-42 ST-4567S  Wednesday      Night     10994.00
# 3060          34 ST-PENN STA-123ACE  Wednesday      Night     10512.40
# 11365                KEW GARDENS-EF  Wednesday      Night     10503.60
# 9593                FLUSHING-MAIN-7  Wednesday      Night      9860.40

# %%
hubs_mask2 = ((grouped_means.STAT_MERGE == 'GRD CNTRL-42 ST-4567S') | 
                (grouped_means.STAT_MERGE == 'TIMES SQ-42 ST-1237ACENQRSW') | 
                (grouped_means.STAT_MERGE == '42 ST-PORT AUTH-1237ACENQRSW') |
                (grouped_means.STAT_MERGE == '34 ST-PENN STA-ACE') |
                (grouped_means.STAT_MERGE == '34 ST-PENN STA-123ACE') |
                (grouped_means.STAT_MERGE == '42 ST-PORT AUTH-1237ACEGNRSW'))
no_hubs_means = grouped_means.drop(grouped_means[hubs_mask2].index)

# %%
(no_hubs_means
 .sort_values(by=['DAY_OF_WK','TIMEOFDAY', 'DELTA_EXITS'], ascending=[True,True,False])
 .groupby(['DAY_OF_WK','TIMEOFDAY'])
 .head())
# Out:
#                      STAT_MERGE  DAY_OF_WK  TIMEOFDAY  DELTA_EXITS
# 2925   34 ST-HERALD SQ-BDFMNQRW     Friday  Afternoon     25900.60
# 884     14 ST-UNION SQ-456LNQRW     Friday  Afternoon     21734.60
# 10002        FULTON ST-2345ACJZ     Friday  Afternoon     14566.40
# 3980       59 ST COLUMBUS-1ABCD     Friday  Afternoon     12277.20
# 4014              59 ST-456NQRW     Friday  Afternoon     10723.20
# 885     14 ST-UNION SQ-456LNQRW     Friday       Dawn     18214.40
# 10003        FULTON ST-2345ACJZ     Friday       Dawn     13843.60
# 13412            PATH NEW WTC-1     Friday       Dawn     11186.20
# 2926   34 ST-HERALD SQ-BDFMNQRW     Friday       Dawn     10174.60
# 3505        47-50 STS ROCK-BDFM     Friday       Dawn      7943.00
# 2927   34 ST-HERALD SQ-BDFMNQRW     Friday    Evening     32644.00
# 886     14 ST-UNION SQ-456LNQRW     Friday    Evening     22837.60
# 9562            FLUSHING-MAIN-7     Friday    Evening     17802.20
# 5785   ATL AV-BARCLAY-2345BDNQR     Friday    Evening     15761.00
# 11231     JKSN HT-ROOSVLT-7EFMR     Friday    Evening     14898.00
# 2928   34 ST-HERALD SQ-BDFMNQRW     Friday    Morning     37422.60
# 3507        47-50 STS ROCK-BDFM     Friday    Morning     34551.20
# 896     14 ST-UNION SQ-456LNQRW   Saturday    Evening     15050.00
# 3992       59 ST COLUMBUS-1ABCD   Saturday    Evening      9123.80
# 9572            FLUSHING-MAIN-7   Saturday    Evening      9108.80
# 11241     JKSN HT-ROOSVLT-7EFMR   Saturday    Evening      9087.00
# 897     14 ST-UNION SQ-456LNQRW   Saturday    Morning     16756.60
# 2938   34 ST-HERALD SQ-BDFMNQRW   Saturday    Morning     14608.80
# 3993       59 ST COLUMBUS-1ABCD   Saturday    Morning     10319.00
# 7700           CANAL ST-6JNQRWZ   Saturday    Morning     10023.20
# 4503                  72 ST-123   Saturday    Morning      8760.40
# 11345            KEW GARDENS-EF   Saturday      Night      3484.20
# 10016        FULTON ST-2345ACJZ   Saturday      Night      2333.80
# 8280               CITY / BUS-1   Saturday      Night      2307.40
# 10391            GROVE STREET-1   Saturday      Night      1744.80
# 11277          JOURNAL SQUARE-1   Saturday      Night      1304.60
# 898     14 ST-UNION SQ-456LNQRW     Sunday  Afternoon     16593.80
# 2939   34 ST-HERALD SQ-BDFMNQRW     Sunday  Afternoon     16581.60
# 3994       59 ST COLUMBUS-1ABCD     Sunday  Afternoon     10541.60
# 4504                  72 ST-123     Sunday  Afternoon      9150.20
# 15267    W 4 ST-WASH SQ-ABCDEFM     Sunday  Afternoon      8343.80
# 899     14 ST-UNION SQ-456LNQRW     Sunday       Dawn      3133.60
# 2940   34 ST-HERALD SQ-BDFMNQRW     Sunday       Dawn      2356.20
# 4505                  72 ST-123     Sunday       Dawn      2075.80
# 7702           CANAL ST-6JNQRWZ     Sunday       Dawn      1865.60
# 5389                  96 ST-123     Sunday       Dawn      1785.40
# 2941   34 ST-HERALD SQ-BDFMNQRW     Sunday    Evening     14873.40
# 900     14 ST-UNION SQ-456LNQRW     Sunday    Evening     11071.80
# 5799   ATL AV-BARCLAY-2345BDNQR     Sunday    Evening      8073.40
# 11245     JKSN HT-ROOSVLT-7EFMR     Sunday    Evening      7962.60
# 9576            FLUSHING-MAIN-7     Sunday    Evening      7651.00
# 901     14 ST-UNION SQ-456LNQRW     Sunday    Morning     12255.40
# 2942   34 ST-HERALD SQ-BDFMNQRW     Sunday    Morning     10988.20
# 7704           CANAL ST-6JNQRWZ     Sunday    Morning      8742.20
# 3997       59 ST COLUMBUS-1ABCD     Sunday    Morning      7627.40
# 4507                  72 ST-123     Sunday    Morning      7239.20
# 2943   34 ST-HERALD SQ-BDFMNQRW     Sunday      Night     10475.20
# 11247     JKSN HT-ROOSVLT-7EFMR     Sunday      Night      9163.60
# 9578            FLUSHING-MAIN-7     Sunday      Night      7755.40
# 902     14 ST-UNION SQ-456LNQRW     Sunday      Night      6587.40
# 6753               BEDFORD AV-L     Sunday      Night      6087.40
# 2944   34 ST-HERALD SQ-BDFMNQRW   Thursday  Afternoon     23971.40
# 903     14 ST-UNION SQ-456LNQRW   Thursday  Afternoon     20549.40
# 10022        FULTON ST-2345ACJZ   Thursday  Afternoon     17783.80
# 3999       59 ST COLUMBUS-1ABCD   Thursday  Afternoon     13113.40
# 4033              59 ST-456NQRW   Thursday  Afternoon     10467.40
# 904     14 ST-UNION SQ-456LNQRW   Thursday       Dawn     19337.80
# 10023        FULTON ST-2345ACJZ   Thursday       Dawn     16098.20
# 13432            PATH NEW WTC-1   Thursday       Dawn     14789.00
# 2945   34 ST-HERALD SQ-BDFMNQRW   Thursday       Dawn     10586.20
# 3524        47-50 STS ROCK-BDFM   Thursday       Dawn      9462.00
# 2946   34 ST-HERALD SQ-BDFMNQRW   Thursday    Evening     34116.20
# 905     14 ST-UNION SQ-456LNQRW   Thursday    Evening     22757.75
# 9581            FLUSHING-MAIN-7   Thursday    Evening     16070.40
# 3014         34 ST-PENN STA-123   Thursday    Evening     16026.40
# 5804   ATL AV-BARCLAY-2345BDNQR   Thursday    Evening     15499.80
# 2947   34 ST-HERALD SQ-BDFMNQRW   Thursday    Morning     39724.60
# 3526        47-50 STS ROCK-BDFM   Thursday    Morning     37089.00
# 10025        FULTON ST-2345ACJZ   Thursday    Morning     26208.00
# 906     14 ST-UNION SQ-456LNQRW   Thursday    Morning     25916.60
# 11763       LEXINGTON AV/53-6EM   Thursday    Morning     24489.40
# 11252     JKSN HT-ROOSVLT-7EFMR   Thursday      Night     10266.20
# 11355            KEW GARDENS-EF   Thursday      Night     10059.00
# 9583            FLUSHING-MAIN-7   Thursday      Night      9965.80
# 2948   34 ST-HERALD SQ-BDFMNQRW   Thursday      Night      9847.00
# 11287          JOURNAL SQUARE-1   Thursday      Night      9026.80
# 2949   34 ST-HERALD SQ-BDFMNQRW    Tuesday  Afternoon     20812.40
# 908     14 ST-UNION SQ-456LNQRW    Tuesday  Afternoon     20002.20
# 10027        FULTON ST-2345ACJZ    Tuesday  Afternoon     13560.80
# 4004       59 ST COLUMBUS-1ABCD    Tuesday  Afternoon     12303.40
# 4038              59 ST-456NQRW    Tuesday  Afternoon      9947.40
# 909     14 ST-UNION SQ-456LNQRW    Tuesday       Dawn     19611.00
# 10028        FULTON ST-2345ACJZ    Tuesday       Dawn     16547.00
# 13437            PATH NEW WTC-1    Tuesday       Dawn     14832.80
# 2950   34 ST-HERALD SQ-BDFMNQRW    Tuesday       Dawn     10989.00
# 3529        47-50 STS ROCK-BDFM    Tuesday       Dawn      9899.80
# 2951   34 ST-HERALD SQ-BDFMNQRW    Tuesday    Evening     35403.00
# 910     14 ST-UNION SQ-456LNQRW    Tuesday    Evening     21404.80
# 9586            FLUSHING-MAIN-7    Tuesday    Evening     18809.00
# 3019         34 ST-PENN STA-123    Tuesday    Evening     15580.80
# 5809   ATL AV-BARCLAY-2345BDNQR    Tuesday    Evening     15478.60
# 2952   34 ST-HERALD SQ-BDFMNQRW    Tuesday    Morning     37477.00
# 3531        47-50 STS ROCK-BDFM    Tuesday    Morning     36391.20
# 10030        FULTON ST-2345ACJZ    Tuesday    Morning     30215.80
# 911     14 ST-UNION SQ-456LNQRW    Tuesday    Morning     26145.80
# 13439            PATH NEW WTC-1    Tuesday    Morning     26078.00
# 11360            KEW GARDENS-EF    Tuesday      Night     10065.40
# 11257     JKSN HT-ROOSVLT-7EFMR    Tuesday      Night      9467.20
# 9588            FLUSHING-MAIN-7    Tuesday      Night      9316.40
# 2953   34 ST-HERALD SQ-BDFMNQRW    Tuesday      Night      8135.20
# 11292          JOURNAL SQUARE-1    Tuesday      Night      6944.40
# 2954   34 ST-HERALD SQ-BDFMNQRW  Wednesday  Afternoon     23392.40
# 913     14 ST-UNION SQ-456LNQRW  Wednesday  Afternoon     21127.00
# 10032        FULTON ST-2345ACJZ  Wednesday  Afternoon     13620.80
# 4009       59 ST COLUMBUS-1ABCD  Wednesday  Afternoon     13375.80
# 4043              59 ST-456NQRW  Wednesday  Afternoon     10610.20
# 914     14 ST-UNION SQ-456LNQRW  Wednesday       Dawn     20026.40
# 10033        FULTON ST-2345ACJZ  Wednesday       Dawn     17401.80
# 13442            PATH NEW WTC-1  Wednesday       Dawn     14277.60
# 2955   34 ST-HERALD SQ-BDFMNQRW  Wednesday       Dawn     10789.40
# 3534        47-50 STS ROCK-BDFM  Wednesday       Dawn      9611.00
# 2956   34 ST-HERALD SQ-BDFMNQRW  Wednesday    Evening     32807.60
# 915     14 ST-UNION SQ-456LNQRW  Wednesday    Evening     22417.60
# 9591            FLUSHING-MAIN-7  Wednesday    Evening     18741.80
# 5814   ATL AV-BARCLAY-2345BDNQR  Wednesday    Evening     15958.00
# 3024         34 ST-PENN STA-123  Wednesday    Evening     15421.00
# 2957   34 ST-HERALD SQ-BDFMNQRW  Wednesday    Morning     39865.20
# 3536        47-50 STS ROCK-BDFM  Wednesday    Morning     36717.60
# 10035        FULTON ST-2345ACJZ  Wednesday    Morning     29535.40
# 916     14 ST-UNION SQ-456LNQRW  Wednesday    Morning     26395.00
# 13444            PATH NEW WTC-1  Wednesday    Morning     24504.00
# 11365            KEW GARDENS-EF  Wednesday      Night     10503.60
# 9593            FLUSHING-MAIN-7  Wednesday      Night      9860.40
# 11262     JKSN HT-ROOSVLT-7EFMR  Wednesday      Night      9725.40
# 2958   34 ST-HERALD SQ-BDFMNQRW  Wednesday      Night      9367.00
# 11297          JOURNAL SQUARE-1  Wednesday      Night      8569.20

# %%
raw = no_hubs[['DAY_OF_WK','STATION','DELTA_EXITS']]
piv = raw.pivot_table(index='STATION', columns='DAY_OF_WK', aggfunc = 'sum')
piv.sort_values(by=('DELTA_EXITS', 'Monday'), ascending=False,inplace=True)
piv.to_csv('/Users/krw252/output.csv')

# %%
sns.set(style="whitegrid")

path = '/Users/krw252/output_sorted.csv'
data = pd.read_csv(path)

# Make the PairGrid
g = sns.PairGrid(data.sort_values("Avg. Daily", ascending=False),
                 x_vars=data.columns[1:9], y_vars=["STATION"],
                 size=8, aspect=.25)

# Draw a dot plot using the stripplot function
g.map(sns.stripplot, size=10.75, orient="h",
      palette="Reds_r", edgecolor="gray")

# Use the same x axis limits on all columns and add better labels
g.set(xlim=(0, 600000), xlabel="EXITS", ylabel="")

# Use semantically meaningful titles for the columns
titles = ['Average','M','T','W','TH','F','S','SU']

for ax, title in zip(g.axes.flat, titles):

    # Set a different title for each axes
    ax.set(title=title)

    # Make the grid horizontal instead of vertical
    ax.xaxis.grid(False)
    ax.yaxis.grid(True)

sns.despine(left=True, bottom=True)
